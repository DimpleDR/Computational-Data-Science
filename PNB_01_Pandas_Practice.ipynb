# %% [markdown]
# <a href="https://colab.research.google.com/github/DimpleDR/Computational-Data-Science/blob/Practice/PNB_01_Pandas_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Getting and Knowing your Data

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
# YOUR CODE HERE
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://cdn.iisc.talentsprint.com/CDS/Datasets/u.user).

# %% [markdown]
# ### Step 3. Assign it to a variable called users and use the 'user_id' as index

# %%
# YOUR CODE HERE
users = pd.read_csv('/content/bankUser_Data.csv')
users.head()
# Out:
#        ID Customer_ID      Month             Name  Age          SSN  \
# 0  0x160a   CUS_0xd40  September    Aaron Maashoh   23  821-00-0265
# 1  0x160b   CUS_0xd40    October    Aaron Maashoh   24  821-00-0265
# 2  0x160c   CUS_0xd40   November    Aaron Maashoh   24  821-00-0265
# 3  0x160d   CUS_0xd40   December    Aaron Maashoh  24_  821-00-0265
# 4  0x1616  CUS_0x21b1  September  Rick Rothackerj   28  004-07-5839
#
#   Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 0  Scientist      19114.12            1824.843333                  3  ...
# 1  Scientist      19114.12            1824.843333                  3  ...
# 2  Scientist      19114.12            1824.843333                  3  ...
# 3  Scientist      19114.12                    NaN                  3  ...
# 4    _______      34847.84            3037.986667                  2  ...
#
#    Num_Credit_Inquiries  Credit_Mix Outstanding_Debt Credit_Utilization_Ratio  \
# ...

# %% [markdown]
# ### Step 4. See the first 25 entries

# %%
# YOUR CODE HERE
users.head(25)
# Out:
#         ID Customer_ID      Month             Name   Age          SSN  \
# 0   0x160a   CUS_0xd40  September    Aaron Maashoh    23  821-00-0265
# 1   0x160b   CUS_0xd40    October    Aaron Maashoh    24  821-00-0265
# 2   0x160c   CUS_0xd40   November    Aaron Maashoh    24  821-00-0265
# 3   0x160d   CUS_0xd40   December    Aaron Maashoh   24_  821-00-0265
# 4   0x1616  CUS_0x21b1  September  Rick Rothackerj    28  004-07-5839
# 5   0x1617  CUS_0x21b1    October  Rick Rothackerj    28    #F%$D@*&8
# 6   0x1618  CUS_0x21b1   November  Rick Rothackerj    28  004-07-5839
# 7   0x1619  CUS_0x21b1   December  Rick Rothackerj    28  004-07-5839
# 8   0x1622  CUS_0x2dbc  September           Langep    35  486-85-3974
# 9   0x1623  CUS_0x2dbc    October           Langep    35  486-85-3974
# 10  0x1624  CUS_0x2dbc   November              NaN    35  486-85-3974
# 11  0x1625  CUS_0x2dbc   December           Langep    35  486-85-3974
# ...

# %% [markdown]
# ### Step 5. See the last 10 entries

# %%
# YOUR CODE HERE
users.tail(10)
# Out:
#             ID Customer_ID      Month            Name   Age          SSN  \
# 49990  0x25fd8  CUS_0xaf61   November  Chris Wickhamm    50  133-16-7738
# 49991  0x25fd9  CUS_0xaf61   December  Chris Wickhamm   50_  133-16-7738
# 49992  0x25fe2  CUS_0x8600  September  Sarah McBridec    29  031-35-0942
# 49993  0x25fe3  CUS_0x8600    October  Sarah McBridec    29  031-35-0942
# 49994  0x25fe4  CUS_0x8600   November  Sarah McBridec    29  031-35-0942
# 49995  0x25fe5  CUS_0x8600   December  Sarah McBridec  4975  031-35-0942
# 49996  0x25fee  CUS_0x942c  September           Nicks    25  078-73-5990
# 49997  0x25fef  CUS_0x942c    October           Nicks    25  078-73-5990
# 49998  0x25ff0  CUS_0x942c   November           Nicks    25  078-73-5990
# 49999  0x25ff1  CUS_0x942c   December           Nicks    25  078-73-5990
#
#       Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 49990     Writer       37188.1            3097.008333                  1  ...
# ...

# %% [markdown]
# ### Step 6. What is the number of observations in the dataset?

# %%
# YOUR CODE HERE
len(users)
# Out:
# 50000

# %% [markdown]
# ### Step 7. What is the number of columns in the dataset?

# %%
# YOUR CODE HERE
len(users.columns)
# Out:
# 27

# %% [markdown]
# ### Step 8. Print the name of all the columns.

# %%
# YOUR CODE HERE
users.columns
# Out:
# Index(['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
#        'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts',
#        'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan',
#        'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance'],
#       dtype='object')

# %% [markdown]
# ### Step 9. How is the dataset indexed?

# %%
# YOUR CODE HERE
users.index
# Out:
# RangeIndex(start=0, stop=50000, step=1)

# %% [markdown]
# ### Step 10. What is the data type of each column?

# %%
# YOUR CODE HERE
users.dtypes
# Out:
# ID                           object
# Customer_ID                  object
# Month                        object
# Name                         object
# Age                          object
# SSN                          object
# Occupation                   object
# Annual_Income                object
# Monthly_Inhand_Salary       float64
# Num_Bank_Accounts             int64
# Num_Credit_Card               int64
# Interest_Rate                 int64
# Num_of_Loan                  object
# Type_of_Loan                 object
# Delay_from_due_date           int64
# Num_of_Delayed_Payment       object
# Changed_Credit_Limit         object
# Num_Credit_Inquiries        float64
# Credit_Mix                   object
# Outstanding_Debt             object
# Credit_Utilization_Ratio    float64
# Credit_History_Age           object
# Payment_of_Min_Amount        object
# Total_EMI_per_month         float64
# Amount_invested_monthly      object
# Payment_Behaviour            object
# ...

# %% [markdown]
# ### Step 11. Print only the occupation column

# %%
# YOUR CODE HERE
users['Occupation']
# Out:
# 0        Scientist
# 1        Scientist
# 2        Scientist
# 3        Scientist
# 4          _______
#            ...
# 49995    Architect
# 49996     Mechanic
# 49997     Mechanic
# 49998     Mechanic
# 49999     Mechanic
# Name: Occupation, Length: 50000, dtype: object

# %% [markdown]
# ### Step 12. How many different occupations are in this dataset?

# %%
# YOUR CODE HERE
users['Occupation'].nunique()
# Out:
# 16

# %% [markdown]
# ### Step 13. What is the most frequent occupation?

# %%
# YOUR CODE HERE
users['Occupation'].value_counts()
# Out:
# Occupation
# _______          3438
# Lawyer           3324
# Engineer         3212
# Architect        3195
# Mechanic         3168
# Developer        3146
# Accountant       3133
# Media_Manager    3130
# Scientist        3104
# Teacher          3103
# Entrepreneur     3103
# Journalist       3037
# Doctor           3027
# Manager          3000
# Musician         2947
# Writer           2933
# Name: count, dtype: int64

# %%
users['Occupation'].value_counts().idxmax()
# Out:
# '_______'

# %% [markdown]
# ### Step 14. Summarize the DataFrame.

# %%
# YOUR CODE HERE
users.describe()
# Out:
#        Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# count           42502.000000       50000.000000     50000.000000
# mean             4182.004291          16.838260        22.921480
# std              3174.109304         116.396848       129.314804
# min               303.645417          -1.000000         0.000000
# 25%              1625.188333           3.000000         4.000000
# 50%              3086.305000           6.000000         5.000000
# 75%              5934.189094           7.000000         7.000000
# max             15204.633333        1798.000000      1499.000000
#
#        Interest_Rate  Delay_from_due_date  Num_Credit_Inquiries  \
# count   50000.000000         50000.000000          48965.000000
# mean       68.772640            21.052640             30.080200
# std       451.602363            14.860397            196.984121
# min         1.000000            -5.000000              0.000000
# ...

# %% [markdown]
# ### Step 15. Summarize all the columns

# %%
# YOUR CODE HERE
users.describe(include = 'all')
# Out:
#             ID Customer_ID      Month    Name    Age        SSN Occupation  \
# count    50000       50000      50000   44985  50000      50000      50000
# unique   50000       12500          4   10139    976      12501         16
# top     0x160a   CUS_0xd40  September  Stevex     39  #F%$D@*&8    _______
# freq         1           4      12500      22   1493       2828       3438
# mean       NaN         NaN        NaN     NaN    NaN        NaN        NaN
# std        NaN         NaN        NaN     NaN    NaN        NaN        NaN
# min        NaN         NaN        NaN     NaN    NaN        NaN        NaN
# 25%        NaN         NaN        NaN     NaN    NaN        NaN        NaN
# 50%        NaN         NaN        NaN     NaN    NaN        NaN        NaN
# 75%        NaN         NaN        NaN     NaN    NaN        NaN        NaN
# max        NaN         NaN        NaN     NaN    NaN        NaN        NaN
#
# ...

# %% [markdown]
# ### Step 16. Summarize only the occupation column

# %%
# YOUR CODE HERE
users['Occupation'].describe()
# Out:
# count       50000
# unique         16
# top       _______
# freq         3438
# Name: Occupation, dtype: object

# %% [markdown]
# ### Step 17. What is the mean age of users?

# %%
# YOUR CODE HERE
users['Age'] = pd.to_numeric(users['Age'], errors='coerce')
users['Age'].mean(skipna=True)
# Out:
# 110.12099404498875

# %% [markdown]
# ### Step 18. What is the age with least occurrence?

# %%
# YOUR CODE HERE
users['Age'].value_counts().idxmin()
# Out:
# 6411.0
